# %% [markdown]
# # Notes On Knowledge Graphs
# YouTube Video introducing the concept
# https://youtu.be/O-T_6KOXML4?si=7ywcbGX2AAw5-gOv
#
# she mentions that you can use it to speed up RAG approaches because you can map out all the relationships and information in a set of documents and put it into a JSON or some other file, so that when the user submits a querry, you can pull out information from the graph -- it can reference faster than parsing all the docs again.
#
# But it's what you think. Each known or entity of interest is a node, and edges show relationships between the nodes. The edges are text based -- like verbs or other relationhip phrases.... (so knows, is a prequel of, is controled by, upregulates...)
#
# She uses neo4j in the video, but I want a way to build these out programatically
# She uses an llm in the video to build out the graph.
# Starts with the opening article of albert einstein wikipedia page.
#
# prompt based approach
# - you are a top tier algorithm designed for extracting information in structured formats to build a knowledge graph. your task is to identify the entitites and relations requested with the user prompt from a given text. You mus generate the output in a JSON format containing a list with JSON objects. Each object should have the keys: "head", "head_type", "relation", "tail", and 'tail_type". here is one example:
# ---
# Give the text : "Adam is a software engineer in Microsoft since 2009""
# You can extract a relationship in the following format:
#
# {
#   "head": "Adam",
#   "head_type": "person",
#   "relation": "works_for",
#   "tail" : "microsoft",
#   "tail_type": "Company"
# }
#
# Results vary based on the llm out put. so use a good LLM.
#
# ## personal thought
# *My thought is that these knowledge graphs might be able to reveal what an LLM know if you apply it to LLM generated text. If you apply it to the data set, then you can get the complexity and content of the data set -- use graph approaches like path length searches, and counting the number of connections at eachc node --> now what happens when you apply it to image data? graphical approaches to image patches.*

# %% [markdown]
# She will have you use an API key, and then get it from an environment variable... interesting. keep it secret dont share it.

# %%
import langchain
